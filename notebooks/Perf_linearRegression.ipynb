# %% [markdown]
# # Imports

# %%
import pandas as pd
import glob
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, f1_score, mean_squared_error
from sklearn.metrics import classification_report

# %% [markdown]
# # Load data

# %%
datapath = "../data/prediction_test/bg_distributions/separated_dists"
files_m1_ex1 = sorted(glob.glob(f"{datapath}/perf_data_program_*_opencl.csv"))

# %%
all_data = []

# %%
for f1 in files_m1_ex1:
    # file2 will be exactly file1 with another machine name
    f2 = f1.replace("opencl", "gogh")
    
    df_m1 = pd.read_csv(f1)
    df_m2 = pd.read_csv(f2)
    
    # Merge csv's in one df
    df = df_m1.merge(df_m2, on=["program", "run"], suffixes=("_m1", "_m2"))
    all_data.append(df)
    
# Merge all df's
df_all = pd.concat(all_data, ignore_index=True)

# %%
df_all.head()
# Out:
#       program  run  cpu-cycles_m1  instructions_m1  cache-references_m1  \
# 0  program_10    1     5446775489       8648349229                46163
# 1  program_10    2     5322950843       8648416958                40260
# 2  program_10    3     5373986632       8648357574                39263
# 3  program_10    4     5199240656       8648223138                38553
# 4  program_10    5     5263733578       8648291000                38819
#
#    cache-misses_m1  duration_time_m1  cpu-cycles_m2  instructions_m2  \
# 0             8136        1550263802        1334096          1009851
# 1             6775        1510210810        1322786          1021682
# 2             7103        1509293975        1294091          1012946
# 3             9610        1462210298        1306165          1019565
# 4             7208        1476810922        1313125          1015511
#
#    cache-references_m2  cache-misses_m2  duration_time_m2
# 0                94132            25379            734626
# 1                94398            26493            707144
# 2                91863            24226            701494
# 3                93667            24605            731299
# 4                93751            24595            710681

# %% [markdown]
# # Models

# %% [markdown]
# ## Model 1 (sklearn LinearRegression + multiple targets)

# %%
# Features
X = df_all[["cpu-cycles_m1", "instructions_m1", "cache-references_m1", "cache-misses_m1", "duration_time_m1"]]

# Targets
Y = df_all[["cpu-cycles_m2", "instructions_m2", "cache-references_m2", "cache-misses_m2", "duration_time_m2"]]

# %%
# Normalization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split train and test -> TODO: Select test by hand to better measurement
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
# Multi-output linear regression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Prediction
Y_pred = model.predict(X_test)

# %%
# Output
for i, col in enumerate(Y.columns):
    r2 = r2_score(Y_test.iloc[:, i], Y_pred[:, i])
    mse = mean_squared_error(Y_test.iloc[:, i], Y_pred[:, i])
    
    print(f"{col}: R²={r2:.3f}, MSE={mse:.3f}")
# Out:
# cpu-cycles_m2: R²=-0.010, MSE=667663750.909
# instructions_m2: R²=-0.038, MSE=52485455.986
# cache-references_m2: R²=-0.001, MSE=4463077.556
# cache-misses_m2: R²=0.006, MSE=1621465.161
# duration_time_m2: R²=-0.045, MSE=599845131.114

# %% [markdown]
# ## Model 2 (OLS + One to One)

# %%
X = df_all['cpu-cycles_m1']
Y = df_all['cpu-cycles_m2']

# %%
# Reshape
X_reshaped = X.values.reshape(-1, 1)

# Separate train and test
X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, Y, test_size=0.2, random_state=42
)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)

# %%
print(r2)
# Out:
# -0.01773398300861222

# %%
print(mse)
# Out:
# 265215776.14542943

# %%
import statsmodels.api as sm

# %%
pairs = [
    ('cpu-cycles_m1', 'cpu-cycles_m2'),
    ('cache-misses_m1', 'cache-misses_m2'),
    ('instructions_m1', 'instructions_m2'),
    ('cache-references_m1', 'cache-references_m2'),
    ('duration_time_m1', 'duration_time_m2')
]
for xcol, ycol in pairs:
    print(f"REGRESSION: {xcol} -> {ycol}")
    Y = df_all[ycol]
    X = df_all[xcol]
    X = sm.add_constant(X)
    model = sm.OLS(Y, X)
    results = model.fit()

    # Results
    print(results.summary())
    print("\n" * 2)
# Out:
# REGRESSION: cpu-cycles_m1 -> cpu-cycles_m2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          cpu-cycles_m2   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.437
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):              0.231
# Time:                        23:52:57   Log-Likelihood:                -11697.
# No. Observations:                1000   AIC:                         2.340e+04
# Df Residuals:                     998   BIC:                         2.341e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.299e+06   1010.038   1285.966      0.000     1.3e+06     1.3e+06
# cpu-cycles_m1  2.081e-07   1.74e-07      1.199      0.231   -1.32e-07    5.49e-07
# ==============================================================================
# Omnibus:                      164.407   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              490.882
# Skew:                           0.819   Prob(JB):                    2.55e-107
# Kurtosis:                       6.016   Cond. No.                     6.39e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.39e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# REGRESSION: cache-misses_m1 -> cache-misses_m2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        cache-misses_m2   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1105
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):              0.740
# Time:                        23:52:57   Log-Likelihood:                -8601.4
# No. Observations:                1000   AIC:                         1.721e+04
# Df Residuals:                     998   BIC:                         1.722e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.525e+04     46.169    546.909      0.000    2.52e+04    2.53e+04
# cache-misses_m1    -0.0020      0.006     -0.332      0.740      -0.014       0.010
# ==============================================================================
# Omnibus:                      205.899   Durbin-Watson:                   2.374
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              362.512
# Skew:                           1.269   Prob(JB):                     1.91e-79
# Kurtosis:                       4.502   Cond. No.                     8.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# REGRESSION: instructions_m1 -> instructions_m2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        instructions_m2   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.159
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):              0.282
# Time:                        23:52:57   Log-Likelihood:                -10600.
# No. Observations:                1000   AIC:                         2.120e+04
# Df Residuals:                     998   BIC:                         2.121e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            1.018e+06    335.716   3031.169      0.000    1.02e+06    1.02e+06
# instructions_m1 -3.227e-08      3e-08     -1.077      0.282   -9.11e-08    2.66e-08
# ==============================================================================
# Omnibus:                      819.461   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18878.950
# Skew:                           3.686   Prob(JB):                         0.00
# Kurtosis:                      22.969   Cond. No.                     1.22e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# REGRESSION: cache-references_m1 -> cache-references_m2
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     cache-references_m2   R-squared:                       0.001
# Model:                             OLS   Adj. R-squared:                  0.000
# Method:                  Least Squares   F-statistic:                     1.062
# Date:                 Sun, 14 Sep 2025   Prob (F-statistic):              0.303
# Time:                         23:52:57   Log-Likelihood:                -9077.6
# No. Observations:                 1000   AIC:                         1.816e+04
# Df Residuals:                      998   BIC:                         1.817e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 9.34e+04    111.334    838.923      0.000    9.32e+04    9.36e+04
# cache-references_m1    -0.0038      0.004     -1.031      0.303      -0.011       0.003
# ==============================================================================
# Omnibus:                       59.275   Durbin-Watson:                   2.181
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.388
# Skew:                           0.625   Prob(JB):                     1.41e-15
# Kurtosis:                       3.277   Cond. No.                     5.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# REGRESSION: duration_time_m1 -> duration_time_m2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       duration_time_m2   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8989
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):              0.343
# Time:                        23:52:57   Log-Likelihood:                -12199.
# No. Observations:                1000   AIC:                         2.440e+04
# Df Residuals:                     998   BIC:                         2.441e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             7.107e+05   1670.158    425.515      0.000    7.07e+05    7.14e+05
# duration_time_m1 -9.665e-07   1.02e-06     -0.948      0.343   -2.97e-06    1.03e-06
# ==============================================================================
# Omnibus:                     1695.611   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1100815.467
# Skew:                          10.915   Prob(JB):                         0.00
# Kurtosis:                     164.068   Cond. No.                     1.80e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
